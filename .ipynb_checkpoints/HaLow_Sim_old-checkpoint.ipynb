# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import special as sp
from scipy import stats
from enum import Enum

import random

# %%
class Environment(Enum):
  FREE_SPACE = 0,
  URBAN_AREA_CELLULAR_RADIO = 1,
  SHADOWED_URBAN_CELLULAR_RADIO = 2,
  IN_BUILDING_LINE = 3,
  OBSTRUCTED_IN_BUILDING = 4,
  OBSTRUCTED_IN_FACTORY = 5

# %%
def dB2Veces(potencia):
    return pow(10, potencia/10)

# %%
def dBm2pot(dbm):
    return pow(10, dbm/10)*1e-3

# %%
def qfunc(x):
    ## Función Q, calculada con la función de error.
    return 0.5-0.5*sp.erf(x/np.sqrt(2))

# %%
def get_SNRPerSimbol(snr, bw, sps):
    ## snr: SNR de la señal en el receptor.
    ## bw: Ancho de banda de la señal.
    ## sps: símbolos por segundo. 
    snr = dB2Veces(snr)
    return snr*bw/sps

# %%
def get_SimbolsPerSecond(bw, gi):
    ## bw: Ancho de banda de la señal.
    ## gi: Guard interval(Evita ISI(Interferencia inter-simbólica) por rebotes de la señal).
    periodo = 1/bw
    new_periodo = periodo + gi
    return 1/new_periodo

# %%
def get_SER(m, snr, bw, gi):
    ## m: Número de M-QAM
    ## snr: SNR de la señal en el receptor.
    ## bw: Ancho de banda de la señal.
    ## gi: Guard interval(Evita ISI(Interferencia inter-simbólica) por rebotes de la señal).
    sps = get_SimbolsPerSecond(bw, gi)
    gamma = get_SNRPerSimbol(snr, bw, sps)
    #print("Gamma: ", gamma)
    
    return 1-pow((1-(2*(np.sqrt(m)-1)/np.sqrt(m))*qfunc(np.sqrt(3*gamma/(m-1)))), 2)

# %%
def get_PER(n, m, snr, bw, gi):
    ## n: N° de bits en un paquete
    ## m: Número de M-QAM
    ## snr: SNR de la señal en el receptor.
    ## bw: Ancho de banda de la señal.
    ## gi: Guard interval(Evita ISI(Interferencia inter-simbólica) por rebotes de la señal).
    ps = get_SER(m, snr, bw, gi)
    ## n_spp: N° de símbolos en un paquete
    n_spp = int(n/np.log2(m))
    #print("SER: ", ps, "\nN° símbolos por paquete: ", n_spp)
    return 1-pow((1-ps), n_spp)

# %%
def get_friis_propagation(pt, d, longOnda, ple):
    ## pt: Potencia del transmisor. 
    ## d: Distancia hacia el receptor.
    ## longOnda: Longitud de onda de la portadora.
    ## ple: Path Loss Exponent
    friis = (pt*(longOnda**2)/(((4*np.pi)**2)*((d)**ple)))   
    return 10*np.log10(friis/1e-3)

# %%
## return: Potencia de recepcion
def get_2_ray_propagation(pt, d, ht, hr):
    ## pt: Potencia del transmisor. 
    ## d: Distancia hacia el receptor.
    ## ht: Altura de transmisora
    ## hr: Altura de receptora
    L=1
    return 10*np.log10(((pt*(ht**2)*(hr**2))/(d**4)*L)/1e-3)

# %%
def get_exponent_by_enviroment(enviroment):
    if(enviroment == Environment.FREE_SPACE):
        return 2
    elif( enviroment == Environment.URBAN_AREA_CELLULAR_RADIO):
        return random.uniform(2.7, 3.5)
    elif( enviroment == Environment.SHADOWED_URBAN_CELLULAR_RADIO):
        return random.uniform(3.0, 5.0)
    elif( enviroment == Environment.IN_BUILDING_LINE):
        return random.uniform(1.6, 1.8)
    elif( enviroment == Environment.OBSTRUCTED_IN_BUILDING):
        return random.uniform(4.0, 6.0)
    elif( enviroment == Environment.OBSTRUCTED_IN_FACTORY):
        return random.uniform(2.0, 3.0)

# %%
pr = get_friis_propagation(1,1000, 0.33, 2)
print(f"Potencia en el receptor: {pr}[dBm]")
# Out:
# Potencia en el receptor: -61.61391848288417[dBm]

# %%
PER = get_PER(1e3, 16, 10, 1e6, 8e-6)
print(PER)
# Out:
# 0.008249787181468404

# %%
def get_stdRandNum():
    return np.random.standard_normal()

# %%
def isThisPacketWrong(PER):
    area_baja = stats.norm.ppf(PER/2)
    area_alta = stats.norm.ppf(1 - PER/2)
    #print(area_baja, area_alta)
    num = get_stdRandNum()
    if num < area_baja or num > area_alta:
        return True
    else:
        return False

# %%
count = 0
max_num = 10000
for i in range(max_num):
    if isThisPacketWrong(PER):
        count +=1
print(f"N° de paquetes con bits errados: {count}\n", f"Probabilidad de PER experimental: {count/max_num}")
# Out:
# N° de paquetes con bits errados: 83
#  Probabilidad de PER experimental: 0.0083

# %%
def get_RxSNR(S, N):
    S = dB2Veces(S)
    N = dB2Veces(N)
    #print(S, N)
    SNR = S/N
    return 10*np.log10(SNR)

# %%
def simulator(max_iter, env, dist, n_bits, bw, gi):
    p_tx = 30 # [dBm] Tx
    #p_noise = -70 # [dBm] Ruido < --- **Justificar**
    #print(dBm2pot(p_tx), p_inRx)
    errs = 0
    count = 0
    while count != max_iter:

        p_noise = -(random.gauss(80, 10))

        exp = get_exponent_by_enviroment(env)
        p_inRx = get_friis_propagation(dBm2pot(p_tx), dist, 0.33, exp)

        Rx_SNR = get_RxSNR(p_inRx, p_noise)
        #print(Rx_SNR)
        PER = get_PER(1e3, 16, Rx_SNR, bw, gi)
        #print(f"PER: {PER}")
        if PER != 0:
             if isThisPacketWrong(PER):
                    errs +=1
        count +=1
    print(f"N° paquetes errados: {errs}, N° total de paquetes {max_iter}, Tasa de trasmisión efectiva: {(max_iter - errs)/max_iter}")

# %%
simulator(10000, Environment.FREE_SPACE, 250, 1e3, 1e6, 8e-6)
# Out:
# N° paquetes errados: 128, N° total de paquetes 10000, Tasa de trasmisión efectiva: 0.9872

# %%
def simulator(max_iter):
    p_tx = 30 # [dBm] Tx
    mu = 80 # -[dBm]
    sigma = 10 # -[dBm]
    canal_bw = [1e6, 2e6, 4e6, 8e6, 16e6] ## Canales BW
    dist_list = [1, 2, 3, 5, 7, 10,
                 20, 30, 50, 70, 100,
                 200, 300, 500, 700, 1000,
                 2000, 3000, 5000, 7000, 10000] ## Distancias 
    q_am = [2, 4, 16, 64, 256] ## BPSK, QPSK, 16QAM, 64QAM, 256QAM
    gi_list = [4e-6, 8e-6] ## Guard Interval
    n_bits = 1e3
    datos = {}
    errs = 0
    count = 0
    while count != max_iter:
        for env in Environment:
            print(f"Environment: {env}")
            for gi in gi_list:
                print(f"Guard Interval[s]: {gi}")
                for bw in canal_bw:
                    print(f"Channel BW[Hz]: {bw}")
                    for q in q_am:
                        print(f"N° de constelaciónes QAM: {q}")
                        calcular = True
                        for dist in dist_list:
                            if calcular:
                                errs = 0
                                count = 0
                                tasa_efectiva = 1
                                print(f"Distancia al Rx[m]: {dist}")
                                while count != max_iter:
                                    p_noise = -(random.gauss(mu, sigma))

                                    exp = get_exponent_by_enviroment(env)
                                    p_inRx = get_friis_propagation(dBm2pot(p_tx), dist, 0.33, exp)

                                    Rx_SNR = get_RxSNR(p_inRx, p_noise)
                                    #print(Rx_SNR)
                                    PER = get_PER(n_bits, q, Rx_SNR, bw, gi)
                                    #print(f"PER: {PER}")
                                    if PER != 0:
                                         if isThisPacketWrong(PER):
                                                errs +=1

                                    tasa_efectiva = (max_iter - errs)/max_iter
                                    count +=1

                                print(f'''N° paquetes errados: {errs}
                                N° total de paquetes {max_iter}
                                Tasa de trasmisión efectiva: {tasa_efectiva}''')
                            
                            datos[(env, gi, bw, q, dist)] = tasa_efectiva
                            
                            if tasa_efectiva == 0.0:
                                calcular = False
                                
    return datos

# %%
datos = simulator(1e6)
# Out:
# Environment: Environment.FREE_SPACE
# Guard Interval[s]: 4e-06
# Channel BW[Hz]: 1000000.0
# N° de constelaciónes QAM: 2
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 7
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 10
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 20
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 30
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 50
# N° paquetes errados: 1
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999999
# Distancia al Rx[m]: 70
# N° paquetes errados: 6
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999994
# Distancia al Rx[m]: 100
# N° paquetes errados: 38
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999962
# Distancia al Rx[m]: 200
# N° paquetes errados: 380
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.99962
# Distancia al Rx[m]: 300
# N° paquetes errados: 1240
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.99876
# Distancia al Rx[m]: 500
# N° paquetes errados: 5058
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.994942
# Distancia al Rx[m]: 700
# N° paquetes errados: 11161
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.988839
# Distancia al Rx[m]: 1000
# N° paquetes errados: 23680
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.97632
# Distancia al Rx[m]: 2000
# N° paquetes errados: 84307
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.915693
# Distancia al Rx[m]: 3000
# N° paquetes errados: 151881
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.848119
# Distancia al Rx[m]: 5000
# N° paquetes errados: 278729
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.721271
# Distancia al Rx[m]: 7000
# N° paquetes errados: 383636
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.616364
# Distancia al Rx[m]: 10000
# N° paquetes errados: 505617
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.494383
# N° de constelaciónes QAM: 4
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 7
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 10
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 20
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 30
# N° paquetes errados: 1
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999999
# Distancia al Rx[m]: 50
# N° paquetes errados: 20
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.99998
# Distancia al Rx[m]: 70
# N° paquetes errados: 62
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999938
# Distancia al Rx[m]: 100
# N° paquetes errados: 225
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999775
# Distancia al Rx[m]: 200
# N° paquetes errados: 1894
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.998106
# Distancia al Rx[m]: 300
# N° paquetes errados: 5349
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.994651
# Distancia al Rx[m]: 500
# N° paquetes errados: 17390
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.98261
# Distancia al Rx[m]: 700
# N° paquetes errados: 33808
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.966192
# Distancia al Rx[m]: 1000
# N° paquetes errados: 65262
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.934738
# Distancia al Rx[m]: 2000
# N° paquetes errados: 179386
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.820614
# Distancia al Rx[m]: 3000
# N° paquetes errados: 286710
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.71329
# Distancia al Rx[m]: 5000
# N° paquetes errados: 450355
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.549645
# Distancia al Rx[m]: 7000
# N° paquetes errados: 567844
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.432156
# Distancia al Rx[m]: 10000
# N° paquetes errados: 683540
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.31646
# N° de constelaciónes QAM: 16
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 7
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 10
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 20
# N° paquetes errados: 15
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999985
# Distancia al Rx[m]: 30
# N° paquetes errados: 72
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999928
# Distancia al Rx[m]: 50
# N° paquetes errados: 322
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999678
# Distancia al Rx[m]: 70
# N° paquetes errados: 829
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999171
# Distancia al Rx[m]: 100
# N° paquetes errados: 2381
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.997619
# Distancia al Rx[m]: 200
# N° paquetes errados: 12621
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.987379
# Distancia al Rx[m]: 300
# N° paquetes errados: 29646
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.970354
# Distancia al Rx[m]: 500
# N° paquetes errados: 74713
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.925287
# Distancia al Rx[m]: 700
# N° paquetes errados: 125010
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.87499
# Distancia al Rx[m]: 1000
# N° paquetes errados: 200665
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.799335
# Distancia al Rx[m]: 2000
# N° paquetes errados: 404847
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.595153
# Distancia al Rx[m]: 3000
# N° paquetes errados: 544015
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.455985
# Distancia al Rx[m]: 5000
# N° paquetes errados: 708532
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.291468
# Distancia al Rx[m]: 7000
# N° paquetes errados: 799345
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.200655
# Distancia al Rx[m]: 10000
# N° paquetes errados: 874839
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.125161
# N° de constelaciónes QAM: 64
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 7
# N° paquetes errados: 2
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999998
# Distancia al Rx[m]: 10
# N° paquetes errados: 21
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999979
# Distancia al Rx[m]: 20
# N° paquetes errados: 159
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999841
# Distancia al Rx[m]: 30
# N° paquetes errados: 522
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999478
# Distancia al Rx[m]: 50
# N° paquetes errados: 2304
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.997696
# Distancia al Rx[m]: 70
# N° paquetes errados: 5493
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.994507
# Distancia al Rx[m]: 100
# N° paquetes errados: 12765
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.987235
# Distancia al Rx[m]: 200
# N° paquetes errados: 51144
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.948856
# Distancia al Rx[m]: 300
# N° paquetes errados: 100379
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.899621
# Distancia al Rx[m]: 500
# N° paquetes errados: 200615
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.799385
# Distancia al Rx[m]: 700
# N° paquetes errados: 291583
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.708417
# Distancia al Rx[m]: 1000
# N° paquetes errados: 404434
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.595566
# Distancia al Rx[m]: 2000
# N° paquetes errados: 638696
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.361304
# Distancia al Rx[m]: 3000
# N° paquetes errados: 760319
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.239681
# Distancia al Rx[m]: 5000
# N° paquetes errados: 874252
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.125748
# Distancia al Rx[m]: 7000
# N° paquetes errados: 924921
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.075079
# Distancia al Rx[m]: 10000
# N° paquetes errados: 959625
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.040375
# N° de constelaciónes QAM: 256
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 4
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999996
# Distancia al Rx[m]: 5
# N° paquetes errados: 11
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999989
# Distancia al Rx[m]: 7
# N° paquetes errados: 34
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999966
# Distancia al Rx[m]: 10
# N° paquetes errados: 142
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999858
# Distancia al Rx[m]: 20
# N° paquetes errados: 1202
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.998798
# Distancia al Rx[m]: 30
# N° paquetes errados: 3523
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.996477
# Distancia al Rx[m]: 50
# N° paquetes errados: 12400
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.9876
# Distancia al Rx[m]: 70
# N° paquetes errados: 25561
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.974439
# Distancia al Rx[m]: 100
# N° paquetes errados: 49745
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.950255
# Distancia al Rx[m]: 200
# N° paquetes errados: 146934
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.853066
# Distancia al Rx[m]: 300
# N° paquetes errados: 242890
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.75711
# Distancia al Rx[m]: 500
# N° paquetes errados: 398201
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.601799
# Distancia al Rx[m]: 700
# N° paquetes errados: 513849
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.486151
# Distancia al Rx[m]: 1000
# N° paquetes errados: 634205
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.365795
# Distancia al Rx[m]: 2000
# N° paquetes errados: 827086
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.172914
# Distancia al Rx[m]: 3000
# N° paquetes errados: 901867
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.098133
# Distancia al Rx[m]: 5000
# N° paquetes errados: 958621
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.041379
# Distancia al Rx[m]: 7000
# N° paquetes errados: 978590
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.02141
# Distancia al Rx[m]: 10000
# N° paquetes errados: 990065
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.009935
# Channel BW[Hz]: 2000000.0
# N° de constelaciónes QAM: 2
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 7
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 10
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 20
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 30
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 50
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 70
# N° paquetes errados: 6
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999994
# Distancia al Rx[m]: 100
# N° paquetes errados: 7
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999993
# Distancia al Rx[m]: 200
# N° paquetes errados: 148
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999852
# Distancia al Rx[m]: 300
# N° paquetes errados: 505
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999495
# Distancia al Rx[m]: 500
# N° paquetes errados: 2330
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.99767
# Distancia al Rx[m]: 700
# N° paquetes errados: 5640
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.99436
# Distancia al Rx[m]: 1000
# N° paquetes errados: 12820
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.98718
# Distancia al Rx[m]: 2000
# N° paquetes errados: 51452
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.948548
# Distancia al Rx[m]: 3000
# N° paquetes errados: 99818
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.900182
# Distancia al Rx[m]: 5000
# N° paquetes errados: 200871
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.799129
# Distancia al Rx[m]: 7000
# N° paquetes errados: 292096
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.707904
# Distancia al Rx[m]: 10000
# N° paquetes errados: 405438
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.594562
# N° de constelaciónes QAM: 4
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 7
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 10
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 20
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 30
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 50
# N° paquetes errados: 3
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999997
# Distancia al Rx[m]: 70
# N° paquetes errados: 17
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999983
# Distancia al Rx[m]: 100
# N° paquetes errados: 75
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999925
# Distancia al Rx[m]: 200
# N° paquetes errados: 799
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999201
# Distancia al Rx[m]: 300
# N° paquetes errados: 2512
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.997488
# Distancia al Rx[m]: 500
# N° paquetes errados: 8883
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.991117
# Distancia al Rx[m]: 700
# N° paquetes errados: 18794
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.981206
# Distancia al Rx[m]: 1000
# N° paquetes errados: 38702
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.961298
# Distancia al Rx[m]: 2000
# N° paquetes errados: 120897
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.879103
# Distancia al Rx[m]: 3000
# N° paquetes errados: 206389
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.793611
# Distancia al Rx[m]: 5000
# N° paquetes errados: 353062
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.646938
# Distancia al Rx[m]: 7000
# N° paquetes errados: 466207
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.533793
# Distancia al Rx[m]: 10000
# N° paquetes errados: 587650
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.41235
# N° de constelaciónes QAM: 16
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 7
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 10
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 20
# N° paquetes errados: 5
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999995
# Distancia al Rx[m]: 30
# N° paquetes errados: 15
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999985
# Distancia al Rx[m]: 50
# N° paquetes errados: 107
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999893
# Distancia al Rx[m]: 70
# N° paquetes errados: 322
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999678
# Distancia al Rx[m]: 100
# N° paquetes errados: 1002
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.998998
# Distancia al Rx[m]: 200
# N° paquetes errados: 6295
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.993705
# Distancia al Rx[m]: 300
# N° paquetes errados: 16268
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.983732
# Distancia al Rx[m]: 500
# N° paquetes errados: 45120
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.95488
# Distancia al Rx[m]: 700
# N° paquetes errados: 79650
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.92035
# Distancia al Rx[m]: 1000
# N° paquetes errados: 136152
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.863848
# Distancia al Rx[m]: 2000
# N° paquetes errados: 309230
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.69077
# Distancia al Rx[m]: 3000
# N° paquetes errados: 441443
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.558557
# Distancia al Rx[m]: 5000
# N° paquetes errados: 615984
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.384016
# Distancia al Rx[m]: 7000
# N° paquetes errados: 721052
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.278948
# Distancia al Rx[m]: 10000
# N° paquetes errados: 813710
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.18629
# N° de constelaciónes QAM: 64
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 2
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999998
# Distancia al Rx[m]: 7
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 10
# N° paquetes errados: 10
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.99999
# Distancia al Rx[m]: 20
# N° paquetes errados: 34
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999966
# Distancia al Rx[m]: 30
# N° paquetes errados: 221
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999779
# Distancia al Rx[m]: 50
# N° paquetes errados: 1051
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.998949
# Distancia al Rx[m]: 70
# N° paquetes errados: 2614
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.997386
# Distancia al Rx[m]: 100
# N° paquetes errados: 6605
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.993395
# Distancia al Rx[m]: 200
# N° paquetes errados: 29546
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.970454
# Distancia al Rx[m]: 300
# N° paquetes errados: 62257
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.937743
# Distancia al Rx[m]: 500
# N° paquetes errados: 136941
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.863059
# Distancia al Rx[m]: 700
# N° paquetes errados: 210171
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.789829
# Distancia al Rx[m]: 1000
# N° paquetes errados: 310349
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.689651
# Distancia al Rx[m]: 2000
# N° paquetes errados: 540841
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.459159
# Distancia al Rx[m]: 3000
# N° paquetes errados: 674652
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.325348
# Distancia al Rx[m]: 5000
# N° paquetes errados: 814345
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.185655
# Distancia al Rx[m]: 7000
# N° paquetes errados: 881626
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.118374
# Distancia al Rx[m]: 10000
# N° paquetes errados: 932085
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.067915
# N° de constelaciónes QAM: 256
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 2
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999998
# Distancia al Rx[m]: 5
# N° paquetes errados: 3
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999997
# Distancia al Rx[m]: 7
# N° paquetes errados: 12
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999988
# Distancia al Rx[m]: 10
# N° paquetes errados: 49
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999951
# Distancia al Rx[m]: 20
# N° paquetes errados: 518
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999482
# Distancia al Rx[m]: 30
# N° paquetes errados: 1616
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.998384
# Distancia al Rx[m]: 50
# N° paquetes errados: 6195
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.993805
# Distancia al Rx[m]: 70
# N° paquetes errados: 13748
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.986252
# Distancia al Rx[m]: 100
# N° paquetes errados: 28761
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.971239
# Distancia al Rx[m]: 200
# N° paquetes errados: 97303
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.902697
# Distancia al Rx[m]: 300
# N° paquetes errados: 170408
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.829592
# Distancia al Rx[m]: 500
# N° paquetes errados: 305213
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.694787
# Distancia al Rx[m]: 700
# N° paquetes errados: 412524
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.587476
# Distancia al Rx[m]: 1000
# N° paquetes errados: 534660
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.46534
# Distancia al Rx[m]: 2000
# N° paquetes errados: 753668
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.246332
# Distancia al Rx[m]: 3000
# N° paquetes errados: 850348
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.149652
# Distancia al Rx[m]: 5000
# N° paquetes errados: 930352
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.069648
# Distancia al Rx[m]: 7000
# N° paquetes errados: 961381
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.038619
# Distancia al Rx[m]: 10000
# N° paquetes errados: 981295
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.018705
# Channel BW[Hz]: 4000000.0
# N° de constelaciónes QAM: 2
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 7
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 10
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 20
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 30
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 50
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 70
# N° paquetes errados: 1
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999999
# Distancia al Rx[m]: 100
# N° paquetes errados: 4
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999996
# Distancia al Rx[m]: 200
# N° paquetes errados: 56
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999944
# Distancia al Rx[m]: 300
# N° paquetes errados: 184
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999816
# Distancia al Rx[m]: 500
# N° paquetes errados: 1033
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.998967
# Distancia al Rx[m]: 700
# N° paquetes errados: 2443
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.997557
# Distancia al Rx[m]: 1000
# N° paquetes errados: 6087
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.993913
# Distancia al Rx[m]: 2000
# N° paquetes errados: 28096
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.971904
# Distancia al Rx[m]: 3000
# N° paquetes errados: 59350
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.94065
# Distancia al Rx[m]: 5000
# N° paquetes errados: 132842
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.867158
# Distancia al Rx[m]: 7000
# N° paquetes errados: 204897
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.795103
# Distancia al Rx[m]: 10000
# N° paquetes errados: 303547
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.696453
# N° de constelaciónes QAM: 4
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 7
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 10
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 20
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 30
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 50
# N° paquetes errados: 2
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999998
# Distancia al Rx[m]: 70
# N° paquetes errados: 9
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999991
# Distancia al Rx[m]: 100
# N° paquetes errados: 29
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999971
# Distancia al Rx[m]: 200
# N° paquetes errados: 332
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999668
# Distancia al Rx[m]: 300
# N° paquetes errados: 1005
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.998995
# Distancia al Rx[m]: 500
# N° paquetes errados: 4137
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.995863
# Distancia al Rx[m]: 700
# N° paquetes errados: 9290
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.99071
# Distancia al Rx[m]: 1000
# N° paquetes errados: 20759
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.979241
# Distancia al Rx[m]: 2000
# N° paquetes errados: 74317
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.925683
# Distancia al Rx[m]: 3000
# N° paquetes errados: 137562
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.862438
# Distancia al Rx[m]: 5000
# N° paquetes errados: 257825
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.742175
# Distancia al Rx[m]: 7000
# N° paquetes errados: 359059
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.640941
# Distancia al Rx[m]: 10000
# N° paquetes errados: 479107
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.520893
# N° de constelaciónes QAM: 16
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 7
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 10
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 20
# N° paquetes errados: 2
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999998
# Distancia al Rx[m]: 30
# N° paquetes errados: 4
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999996
# Distancia al Rx[m]: 50
# N° paquetes errados: 39
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999961
# Distancia al Rx[m]: 70
# N° paquetes errados: 120
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.99988
# Distancia al Rx[m]: 100
# N° paquetes errados: 413
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999587
# Distancia al Rx[m]: 200
# N° paquetes errados: 2790
# ...
#                                 Tasa de trasmisión efectiva: 0.95157
# Distancia al Rx[m]: 1000
# N° paquetes errados: 88491
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.911509
# Distancia al Rx[m]: 2000
# N° paquetes errados: 225728
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.774272
# Distancia al Rx[m]: 3000
# N° paquetes errados: 343995
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.656005
# Distancia al Rx[m]: 5000
# N° paquetes errados: 515797
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.484203
# Distancia al Rx[m]: 7000
# N° paquetes errados: 629314
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.370686
# Distancia al Rx[m]: 10000
# N° paquetes errados: 739839
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.260161
# N° de constelaciónes QAM: 256
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 7
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 10
# N° paquetes errados: 2
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999998
# Distancia al Rx[m]: 20
# N° paquetes errados: 21
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999979
# Distancia al Rx[m]: 30
# N° paquetes errados: 77
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999923
# Distancia al Rx[m]: 50
# N° paquetes errados: 383
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999617
# Distancia al Rx[m]: 70
# N° paquetes errados: 1072
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.998928
# Distancia al Rx[m]: 100
# N° paquetes errados: 2949
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.997051
# Distancia al Rx[m]: 200
# N° paquetes errados: 15653
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.984347
# Distancia al Rx[m]: 300
# N° paquetes errados: 35386
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.964614
# Distancia al Rx[m]: 500
# N° paquetes errados: 86108
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.913892
# Distancia al Rx[m]: 700
# N° paquetes errados: 141997
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.858003
# Distancia al Rx[m]: 1000
# N° paquetes errados: 222517
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.777483
# Distancia al Rx[m]: 2000
# N° paquetes errados: 433813
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.566187
# Distancia al Rx[m]: 3000
# N° paquetes errados: 572454
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.427546
# Distancia al Rx[m]: 5000
# N° paquetes errados: 733704
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.266296
# Distancia al Rx[m]: 7000
# N° paquetes errados: 819618
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.180382
# Distancia al Rx[m]: 10000
# N° paquetes errados: 890072
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.109928
# Guard Interval[s]: 8e-06
# Channel BW[Hz]: 1000000.0
# N° de constelaciónes QAM: 2
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 7
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 10
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 20
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 30
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 50
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 70
# N° paquetes errados: 3
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999997
# Distancia al Rx[m]: 100
# N° paquetes errados: 17
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999983
# Distancia al Rx[m]: 200
# N° paquetes errados: 142
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999858
# Distancia al Rx[m]: 300
# N° paquetes errados: 517
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999483
# Distancia al Rx[m]: 500
# N° paquetes errados: 2278
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.997722
# Distancia al Rx[m]: 700
# N° paquetes errados: 5521
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.994479
# Distancia al Rx[m]: 1000
# N° paquetes errados: 12745
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.987255
# Distancia al Rx[m]: 2000
# N° paquetes errados: 51233
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.948767
# Distancia al Rx[m]: 3000
# N° paquetes errados: 99678
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.900322
# Distancia al Rx[m]: 5000
# N° paquetes errados: 200406
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.799594
# Distancia al Rx[m]: 7000
# N° paquetes errados: 292156
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.707844
# Distancia al Rx[m]: 10000
# N° paquetes errados: 404458
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.595542
# N° de constelaciónes QAM: 4
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 7
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 10
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 20
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 30
# N° paquetes errados: 1
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999999
# Distancia al Rx[m]: 50
# N° paquetes errados: 3
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999997
# Distancia al Rx[m]: 70
# N° paquetes errados: 20
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.99998
# Distancia al Rx[m]: 100
# N° paquetes errados: 79
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999921
# Distancia al Rx[m]: 200
# N° paquetes errados: 775
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999225
# Distancia al Rx[m]: 300
# N° paquetes errados: 2502
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.997498
# Distancia al Rx[m]: 500
# N° paquetes errados: 8894
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.991106
# Distancia al Rx[m]: 700
# N° paquetes errados: 18995
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.981005
# Distancia al Rx[m]: 1000
# N° paquetes errados: 38564
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.961436
# Distancia al Rx[m]: 2000
# N° paquetes errados: 121458
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.878542
# Distancia al Rx[m]: 3000
# N° paquetes errados: 206471
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.793529
# Distancia al Rx[m]: 5000
# N° paquetes errados: 352934
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.647066
# Distancia al Rx[m]: 7000
# N° paquetes errados: 465804
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.534196
# Distancia al Rx[m]: 10000
# N° paquetes errados: 588196
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.411804
# N° de constelaciónes QAM: 16
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 7
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 10
# N° paquetes errados: 0
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 20
# N° paquetes errados: 1
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999999
# Distancia al Rx[m]: 30
# N° paquetes errados: 13
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999987
# Distancia al Rx[m]: 50
# N° paquetes errados: 114
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999886
# Distancia al Rx[m]: 70
# N° paquetes errados: 331
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.999669
# Distancia al Rx[m]: 100
# N° paquetes errados: 1026
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.998974
# Distancia al Rx[m]: 200
# N° paquetes errados: 6459
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.993541
# Distancia al Rx[m]: 300
# N° paquetes errados: 16434
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.983566
# Distancia al Rx[m]: 500
# N° paquetes errados: 45405
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.954595
# Distancia al Rx[m]: 700
# N° paquetes errados: 80239
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.919761
# Distancia al Rx[m]: 1000
# N° paquetes errados: 137010
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.86299
# Distancia al Rx[m]: 2000
# N° paquetes errados: 309772
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.690228
# Distancia al Rx[m]: 3000
# N° paquetes errados: 442234
#                                 N° total de paquetes 1000000.0
#                                 Tasa de trasmisión efectiva: 0.557766
# Distancia al Rx[m]: 5000

# %%
def plotGraph(data_x, data_y, env, gi, bw, q):
    lenght = len(data_x)
    #x = np.linspace(0, lenght, num=lenght, endpoint=False) ## Equiespaciamos max_In en interval

    # Note that even in the OO-style, we use `.pyplot.figure` to create the figure.
    fig, ax = plt.subplots(figsize=(15,10))  # Create a figure and an axes.
    ax.plot(data_x, data_y, "-bo", label='Goodput')  # Plot some data on the axes.
    ax.set_xlabel('Distancia[m]')  # Add an x-label to the axes.
    ax.set_ylabel('Tasa efectiva paquetes(Goodput)')  # Add a y-label to the axes.
    ax.set_title(f"Goodput. vs Distancia[m]")  # Add a title to the axes.
    ax.legend()  # Add a legend.
    ax.text(6500, 1, f'\n{"#"*len(str(env))}\nAmbiente: {env}\n' +
           f'Guard Interval[us]: {gi/1e-6}\n' +
           f'Bw del canal[MHz]: {bw/1e6}\n' + 
           f'M-QAM: {q}', fontsize=12)
    for i in range(lenght):
        ax.annotate(str(data_x[i]), # this is the text
                     (data_x[i], data_y[i]), # these are the coordinates to position the label
                     textcoords="offset points", # how to position the text
                     xytext=(0,10), # distance from text to points (x,y)
                     ha='center') # horizontal alignment can be left, right or center

# %%
def plotAllGraphs(datos):
    canal_bw = [1e6, 2e6, 4e6, 8e6, 16e6] ## Canales BW
    dist_list = [1, 2, 3, 5, 7, 10,
                 20, 30, 50, 70, 100,
                 200, 300, 500, 700, 1000,
                 2000, 3000, 5000, 7000, 10000] ## Distancias 
    q_am = [2, 4, 16, 64, 256] ## BPSK, QPSK, 16QAM, 64QAM, 256QAM
    gi_list = [4e-6, 8e-6] ## Guard Interval
    data = {}
    tmp = []
    for env in Environment:
        print(env)
        data = {k: v for k, v in datos.items() if k[0]==env}
        for gi in gi_list:
            for bw in canal_bw:
                for q in q_am:
                    tmp = []
                    for dist in dist_list:
                        tmp.append(data[env, gi, bw, q, dist])
                    print(tmp)
                    tmp = np.array(tmp)
                    plotGraph(dist_list, tmp, env, gi, bw, q)

# %%
plotAllGraphs(datos)
