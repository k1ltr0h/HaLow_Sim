# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import special as sp
from scipy import stats
from enum import Enum

import random

# %%
class Environment(Enum):
  FREE_SPACE = 0,
  URBAN_AREA_CELLULAR_RADIO = 1,
  SHADOWED_URBAN_CELLULAR_RADIO = 2,
  IN_BUILDING_LINE = 3,
  OBSTRUCTED_IN_BUILDING = 4,
  OBSTRUCTED_IN_FACTORY = 5

# %%
def dB2Veces(potencia):
    return pow(10, potencia/10)

# %%
def dBm2pot(dbm):
    return pow(10, dbm/10)*1e-3

# %%
def qfunc(x):
    ## Función Q, calculada con la función de error.
    return 0.5-0.5*sp.erf(x/np.sqrt(2))

# %%
def get_SNRPerSimbol(snr, bw, sps):
    ## snr: SNR de la señal en el receptor.
    ## bw: Ancho de banda de la señal.
    ## sps: símbolos por segundo. 
    snr = dB2Veces(snr)
    return snr*bw/sps

# %%
def get_SimbolsPerSecond(bw, gi):
    ## bw: Ancho de banda de la señal.
    ## gi: Guard interval(Evita ISI(Interferencia inter-simbólica) por rebotes de la señal).
    periodo = 1/bw
    new_periodo = periodo + gi
    return 1/new_periodo

# %%
def get_SER(m, snr, bw, gi):
    ## m: Número de M-QAM
    ## snr: SNR de la señal en el receptor.
    ## bw: Ancho de banda de la señal.
    ## gi: Guard interval(Evita ISI(Interferencia inter-simbólica) por rebotes de la señal).
    sps = get_SimbolsPerSecond(bw, gi)
    gamma = get_SNRPerSimbol(snr, bw, sps)
    #print("Gamma: ", gamma)
    
    return 1-pow((1-(2*(np.sqrt(m)-1)/np.sqrt(m))*qfunc(np.sqrt(3*gamma/(m-1)))), 2)

# %%
def get_PER(n, m, snr, bw, gi):
    ## n: N° de bits en un paquete
    ## m: Número de M-QAM
    ## snr: SNR de la señal en el receptor.
    ## bw: Ancho de banda de la señal.
    ## gi: Guard interval(Evita ISI(Interferencia inter-simbólica) por rebotes de la señal).
    ps = get_SER(m, snr, bw, gi)
    ## n_spp: N° de símbolos en un paquete
    n_spp = int(n/np.log2(m))
    #print("SER: ", ps, "\nN° símbolos por paquete: ", n_spp)
    return 1-pow((1-ps), n_spp)

# %%
def get_friis_propagation(pt, d, longOnda, ple):
    ## pt: Potencia del transmisor. 
    ## d: Distancia hacia el receptor.
    ## longOnda: Longitud de onda de la portadora.
    ## ple: Path Loss Exponent
    friis = (pt*(longOnda**2)/(((4*np.pi)**2)*((d)**ple)))   
    return 10*np.log10(friis/1e-3)

# %%
## return: Potencia de recepcion
def get_2_ray_propagation(pt, d, ht, hr):
    ## pt: Potencia del transmisor. 
    ## d: Distancia hacia el receptor.
    ## ht: Altura de transmisora
    ## hr: Altura de receptora
    L=1
    return 10*np.log10(((pt*(ht**2)*(hr**2))/(d**4)*L)/1e-3)

# %%
def get_exponent_by_enviroment(enviroment):
    if(enviroment == Environment.FREE_SPACE):
        return 2
    elif( enviroment == Environment.URBAN_AREA_CELLULAR_RADIO):
        return random.uniform(2.7, 3.5)
    elif( enviroment == Environment.SHADOWED_URBAN_CELLULAR_RADIO):
        return random.uniform(3.0, 5.0)
    elif( enviroment == Environment.IN_BUILDING_LINE):
        return random.uniform(1.6, 1.8)
    elif( enviroment == Environment.OBSTRUCTED_IN_BUILDING):
        return random.uniform(4.0, 6.0)
    elif( enviroment == Environment.OBSTRUCTED_IN_FACTORY):
        return random.uniform(2.0, 3.0)

# %%
pr = get_friis_propagation(1,1000, 0.33, 2)
print(f"Potencia en el receptor: {pr}[dBm]")
# Out:
# Potencia en el receptor: -61.61391848288417[dBm]

# %%
PER = get_PER(1e3, 16, 10, 1e6, 8e-6)
print(PER)
# Out:
# 0.008249787181468404

# %%
def get_stdRandNum():
    return np.random.standard_normal()

# %%
def isThisPacketWrong(PER):
    area_baja = stats.norm.ppf(PER/2)
    area_alta = stats.norm.ppf(1 - PER/2)
    #print(area_baja, area_alta)
    num = get_stdRandNum()
    if num < area_baja or num > area_alta:
        return True
    else:
        return False

# %%
count = 0
max_num = 10000
for i in range(max_num):
    if isThisPacketWrong(PER):
        count +=1
print(f"N° de paquetes con bits errados: {count}\n", f"Probabilidad de PER experimental: {count/max_num}")
# Out:
# N° de paquetes con bits errados: 82
#  Probabilidad de PER experimental: 0.0082

# %%
def get_RxSNR(S, N):
    S = dB2Veces(S)
    N = dB2Veces(N)
    #print(S, N)
    SNR = S/N
    return 10*np.log10(SNR)

# %%
def simulator(max_iter, env, dist, n_bits, bw, gi):
    p_tx = 30 # [dBm] Potencia Tx
    p_min = -86 # [dBm] Sensibilidad del receptor
    #p_noise = -70 # [dBm] Ruido < --- **Justificar**
    #print(dBm2pot(p_tx), p_inRx)
    errs = 0
    count = 0
    while count != max_iter:

        p_noise = -(random.gauss(80, 10))

        exp = get_exponent_by_enviroment(env)
        p_inRx = get_friis_propagation(dBm2pot(p_tx), dist, 0.33, exp)
        
        if p_inRx < p_min:
            errs +=1
        else:
            Rx_SNR = get_RxSNR(p_inRx, p_noise)
            #print(Rx_SNR)
            PER = get_PER(n_bits, 16, Rx_SNR, bw, gi)
            #print(f"PER: {PER}")
            if PER != 0:
                 if isThisPacketWrong(PER):
                        errs +=1

        count +=1
    print(f"N° paquetes errados: {errs}, N° total de paquetes {max_iter}, Tasa de trasmisión efectiva: {(max_iter - errs)/max_iter}")

# %%
simulator(10000, Environment.FREE_SPACE, 250, 1e3, 1e6, 8e-6)
# Out:
# N° paquetes errados: 109, N° total de paquetes 10000, Tasa de trasmisión efectiva: 0.9891

# %%
def simulator(max_iter):
    p_tx = 30 # [dBm] Potencia Tx
    p_min = -86 # [dBm] Sensibilidad del receptor
    mu = 80 # -[dBm]
    sigma = 10 # -[dBm]
    canal_bw = [1e6, 2e6, 4e6, 8e6, 16e6] ## Canales BW
    dist_list = [1, 2, 3, 5, 7, 10,
                 20, 30, 50, 70, 100,
                 200, 300, 500, 700, 1000,
                 2000, 3000, 5000, 7000, 10000] ## Distancias 
    q_am = [2, 4, 16, 64, 256] ## BPSK, QPSK, 16QAM, 64QAM, 256QAM
    gi_list = [4e-6, 8e-6] ## Guard Interval
    n_bits = 1e3
    datos = {}
    errs = 0
    count = 0
    while count != max_iter:
        for env in Environment:
            print(f"Environment: {env}")
            for gi in gi_list:
                print(f"Guard Interval[s]: {gi}")
                for bw in canal_bw:
                    print(f"Channel BW[Hz]: {bw}")
                    for q in q_am:
                        print(f"N° de constelaciónes QAM: {q}")
                        calcular = True
                        for dist in dist_list:
                            if calcular:
                                errs = 0
                                count = 0
                                tasa_efectiva = 1
                                print(f"Distancia al Rx[m]: {dist}")
                                while count != max_iter:
                                    #p_noise = -(np.random.normal(mu, sigma)) ## Demora más u.u
                                    p_noise = -(random.gauss(mu, sigma))

                                    exp = get_exponent_by_enviroment(env)
                                    p_inRx = get_friis_propagation(dBm2pot(p_tx), dist, 0.33, exp)
                                    
                                    if p_inRx < p_min:
                                        errs +=1
                                    else:
                                        Rx_SNR = get_RxSNR(p_inRx, p_noise)
                                        #print(Rx_SNR)
                                        PER = get_PER(n_bits, q, Rx_SNR, bw, gi)
                                        #print(f"PER: {PER}")
                                        if PER != 0:
                                             if isThisPacketWrong(PER):
                                                    errs +=1

                                    tasa_efectiva = (max_iter - errs)/max_iter
                                    count +=1

                                print(f'''N° paquetes errados: {errs}
                                N° total de paquetes {max_iter}
                                Tasa de trasmisión efectiva: {tasa_efectiva}''')
                            
                            datos[(env, gi, bw, q, dist)] = tasa_efectiva
                            
                            if tasa_efectiva == 0.0:
                                calcular = False
                                
    return datos

# %%
# %time datos = simulator(5e5)
# Out:
# Environment: Environment.FREE_SPACE
# Guard Interval[s]: 4e-06
# Channel BW[Hz]: 1000000.0
# N° de constelaciónes QAM: 2
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 7
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 10
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 20
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 30
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 50
# N° paquetes errados: 1
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999998
# Distancia al Rx[m]: 70
# N° paquetes errados: 6
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999988
# Distancia al Rx[m]: 100
# N° paquetes errados: 21
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999958
# Distancia al Rx[m]: 200
# N° paquetes errados: 189
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999622
# Distancia al Rx[m]: 300
# N° paquetes errados: 646
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.998708
# Distancia al Rx[m]: 500
# N° paquetes errados: 2452
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.995096
# Distancia al Rx[m]: 700
# N° paquetes errados: 5622
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.988756
# Distancia al Rx[m]: 1000
# N° paquetes errados: 11928
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.976144
# Distancia al Rx[m]: 2000
# N° paquetes errados: 42362
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.915276
# Distancia al Rx[m]: 3000
# N° paquetes errados: 76315
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.84737
# Distancia al Rx[m]: 5000
# N° paquetes errados: 139569
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.720862
# Distancia al Rx[m]: 7000
# N° paquetes errados: 192593
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.614814
# Distancia al Rx[m]: 10000
# N° paquetes errados: 251994
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.496012
# N° de constelaciónes QAM: 4
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 7
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 10
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 20
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 30
# N° paquetes errados: 2
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999996
# Distancia al Rx[m]: 50
# N° paquetes errados: 8
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999984
# Distancia al Rx[m]: 70
# N° paquetes errados: 37
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999926
# Distancia al Rx[m]: 100
# N° paquetes errados: 119
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999762
# Distancia al Rx[m]: 200
# N° paquetes errados: 967
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.998066
# Distancia al Rx[m]: 300
# N° paquetes errados: 2557
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.994886
# Distancia al Rx[m]: 500
# N° paquetes errados: 8618
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.982764
# Distancia al Rx[m]: 700
# N° paquetes errados: 17133
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.965734
# Distancia al Rx[m]: 1000
# N° paquetes errados: 32492
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.935016
# Distancia al Rx[m]: 2000
# N° paquetes errados: 89978
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.820044
# Distancia al Rx[m]: 3000
# N° paquetes errados: 143181
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.713638
# Distancia al Rx[m]: 5000
# N° paquetes errados: 225747
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.548506
# Distancia al Rx[m]: 7000
# N° paquetes errados: 283219
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.433562
# Distancia al Rx[m]: 10000
# N° paquetes errados: 342048
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.315904
# N° de constelaciónes QAM: 16
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 7
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 10
# N° paquetes errados: 1
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999998
# Distancia al Rx[m]: 20
# N° paquetes errados: 4
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999992
# Distancia al Rx[m]: 30
# N° paquetes errados: 28
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999944
# Distancia al Rx[m]: 50
# N° paquetes errados: 134
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999732
# Distancia al Rx[m]: 70
# N° paquetes errados: 421
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999158
# Distancia al Rx[m]: 100
# N° paquetes errados: 1175
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.99765
# Distancia al Rx[m]: 200
# N° paquetes errados: 6387
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.987226
# Distancia al Rx[m]: 300
# N° paquetes errados: 15034
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.969932
# Distancia al Rx[m]: 500
# N° paquetes errados: 37291
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.925418
# Distancia al Rx[m]: 700
# N° paquetes errados: 62353
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.875294
# Distancia al Rx[m]: 1000
# N° paquetes errados: 99699
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.800602
# Distancia al Rx[m]: 2000
# N° paquetes errados: 202338
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.595324
# Distancia al Rx[m]: 3000
# N° paquetes errados: 272406
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.455188
# Distancia al Rx[m]: 5000
# N° paquetes errados: 354279
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.291442
# Distancia al Rx[m]: 7000
# N° paquetes errados: 399882
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.200236
# Distancia al Rx[m]: 10000
# N° paquetes errados: 437449
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.125102
# N° de constelaciónes QAM: 64
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 1
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999998
# Distancia al Rx[m]: 7
# N° paquetes errados: 1
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999998
# Distancia al Rx[m]: 10
# N° paquetes errados: 5
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.99999
# Distancia al Rx[m]: 20
# N° paquetes errados: 62
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999876
# Distancia al Rx[m]: 30
# N° paquetes errados: 247
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999506
# Distancia al Rx[m]: 50
# N° paquetes errados: 1188
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.997624
# Distancia al Rx[m]: 70
# N° paquetes errados: 2749
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.994502
# Distancia al Rx[m]: 100
# N° paquetes errados: 6571
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.986858
# Distancia al Rx[m]: 200
# N° paquetes errados: 25657
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.948686
# Distancia al Rx[m]: 300
# N° paquetes errados: 49882
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.900236
# Distancia al Rx[m]: 500
# N° paquetes errados: 99972
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.800056
# Distancia al Rx[m]: 700
# N° paquetes errados: 145912
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.708176
# Distancia al Rx[m]: 1000
# N° paquetes errados: 202057
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.595886
# Distancia al Rx[m]: 2000
# N° paquetes errados: 319710
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.36058
# Distancia al Rx[m]: 3000
# N° paquetes errados: 380276
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.239448
# Distancia al Rx[m]: 5000
# N° paquetes errados: 437442
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.125116
# Distancia al Rx[m]: 7000
# N° paquetes errados: 462485
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.07503
# Distancia al Rx[m]: 10000
# N° paquetes errados: 479689
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.040622
# N° de constelaciónes QAM: 256
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 5
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.99999
# Distancia al Rx[m]: 7
# N° paquetes errados: 19
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999962
# Distancia al Rx[m]: 10
# N° paquetes errados: 67
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999866
# Distancia al Rx[m]: 20
# N° paquetes errados: 604
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.998792
# Distancia al Rx[m]: 30
# N° paquetes errados: 1867
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.996266
# Distancia al Rx[m]: 50
# N° paquetes errados: 6275
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.98745
# Distancia al Rx[m]: 70
# N° paquetes errados: 12605
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.97479
# Distancia al Rx[m]: 100
# N° paquetes errados: 24966
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.950068
# Distancia al Rx[m]: 200
# N° paquetes errados: 73571
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.852858
# Distancia al Rx[m]: 300
# N° paquetes errados: 121300
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.7574
# Distancia al Rx[m]: 500
# N° paquetes errados: 199794
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.600412
# Distancia al Rx[m]: 700
# N° paquetes errados: 257213
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.485574
# Distancia al Rx[m]: 1000
# N° paquetes errados: 316955
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.36609
# Distancia al Rx[m]: 2000
# N° paquetes errados: 413253
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.173494
# Distancia al Rx[m]: 3000
# N° paquetes errados: 450950
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.0981
# Distancia al Rx[m]: 5000
# N° paquetes errados: 479188
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.041624
# Distancia al Rx[m]: 7000
# N° paquetes errados: 489098
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.021804
# Distancia al Rx[m]: 10000
# N° paquetes errados: 495144
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.009712
# Channel BW[Hz]: 2000000.0
# N° de constelaciónes QAM: 2
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 7
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 10
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 20
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 30
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 50
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 70
# N° paquetes errados: 1
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999998
# Distancia al Rx[m]: 100
# N° paquetes errados: 3
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999994
# Distancia al Rx[m]: 200
# N° paquetes errados: 76
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999848
# Distancia al Rx[m]: 300
# N° paquetes errados: 297
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999406
# Distancia al Rx[m]: 500
# N° paquetes errados: 1255
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.99749
# Distancia al Rx[m]: 700
# N° paquetes errados: 2712
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.994576
# Distancia al Rx[m]: 1000
# N° paquetes errados: 6522
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.986956
# Distancia al Rx[m]: 2000
# N° paquetes errados: 25405
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.94919
# Distancia al Rx[m]: 3000
# N° paquetes errados: 49704
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.900592
# Distancia al Rx[m]: 5000
# N° paquetes errados: 100211
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.799578
# Distancia al Rx[m]: 7000
# N° paquetes errados: 145760
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.70848
# Distancia al Rx[m]: 10000
# N° paquetes errados: 202738
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.594524
# N° de constelaciónes QAM: 4
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 7
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 10
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 20
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 30
# N° paquetes errados: 2
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999996
# Distancia al Rx[m]: 50
# N° paquetes errados: 6
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999988
# Distancia al Rx[m]: 70
# N° paquetes errados: 17
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999966
# Distancia al Rx[m]: 100
# N° paquetes errados: 43
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999914
# Distancia al Rx[m]: 200
# N° paquetes errados: 386
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999228
# Distancia al Rx[m]: 300
# N° paquetes errados: 1257
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.997486
# Distancia al Rx[m]: 500
# N° paquetes errados: 4413
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.991174
# Distancia al Rx[m]: 700
# N° paquetes errados: 9362
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.981276
# Distancia al Rx[m]: 1000
# N° paquetes errados: 18928
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.962144
# Distancia al Rx[m]: 2000
# N° paquetes errados: 60455
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.87909
# Distancia al Rx[m]: 3000
# N° paquetes errados: 103406
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.793188
# Distancia al Rx[m]: 5000
# N° paquetes errados: 176618
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.646764
# Distancia al Rx[m]: 7000
# N° paquetes errados: 233040
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.53392
# Distancia al Rx[m]: 10000
# N° paquetes errados: 294222
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.411556
# N° de constelaciónes QAM: 16
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 7
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 10
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 20
# N° paquetes errados: 3
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999994
# Distancia al Rx[m]: 30
# N° paquetes errados: 8
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999984
# Distancia al Rx[m]: 50
# N° paquetes errados: 55
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.99989
# Distancia al Rx[m]: 70
# N° paquetes errados: 183
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999634
# Distancia al Rx[m]: 100
# N° paquetes errados: 475
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.99905
# Distancia al Rx[m]: 200
# N° paquetes errados: 3239
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.993522
# Distancia al Rx[m]: 300
# N° paquetes errados: 8078
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.983844
# Distancia al Rx[m]: 500
# N° paquetes errados: 22373
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.955254
# Distancia al Rx[m]: 700
# N° paquetes errados: 39822
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.920356
# Distancia al Rx[m]: 1000
# N° paquetes errados: 68459
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.863082
# Distancia al Rx[m]: 2000
# N° paquetes errados: 154327
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.691346
# Distancia al Rx[m]: 3000
# N° paquetes errados: 220967
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.558066
# Distancia al Rx[m]: 5000
# N° paquetes errados: 308604
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.382792
# Distancia al Rx[m]: 7000
# N° paquetes errados: 360517
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.278966
# Distancia al Rx[m]: 10000
# N° paquetes errados: 407363
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.185274
# N° de constelaciónes QAM: 64
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 7
# N° paquetes errados: 1
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999998
# Distancia al Rx[m]: 10
# N° paquetes errados: 1
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999998
# Distancia al Rx[m]: 20
# N° paquetes errados: 29
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999942
# Distancia al Rx[m]: 30
# N° paquetes errados: 117
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999766
# Distancia al Rx[m]: 50
# N° paquetes errados: 511
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.998978
# Distancia al Rx[m]: 70
# N° paquetes errados: 1327
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.997346
# Distancia al Rx[m]: 100
# N° paquetes errados: 3232
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.993536
# Distancia al Rx[m]: 200
# N° paquetes errados: 14670
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.97066
# Distancia al Rx[m]: 300
# N° paquetes errados: 31512
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.936976
# Distancia al Rx[m]: 500
# N° paquetes errados: 68340
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.86332
# Distancia al Rx[m]: 700
# N° paquetes errados: 104998
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.790004
# Distancia al Rx[m]: 1000
# N° paquetes errados: 154842
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.690316
# Distancia al Rx[m]: 2000
# N° paquetes errados: 270375
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.45925
# Distancia al Rx[m]: 3000
# N° paquetes errados: 337041
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.325918
# Distancia al Rx[m]: 5000
# N° paquetes errados: 406981
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.186038
# Distancia al Rx[m]: 7000
# N° paquetes errados: 441161
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.117678
# Distancia al Rx[m]: 10000
# N° paquetes errados: 466299
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.067402
# N° de constelaciónes QAM: 256
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 7
# N° paquetes errados: 9
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999982
# Distancia al Rx[m]: 10
# N° paquetes errados: 35
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.99993
# Distancia al Rx[m]: 20
# N° paquetes errados: 238
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999524
# Distancia al Rx[m]: 30
# N° paquetes errados: 798
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.998404
# Distancia al Rx[m]: 50
# N° paquetes errados: 2959
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.994082
# Distancia al Rx[m]: 70
# N° paquetes errados: 6783
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.986434
# Distancia al Rx[m]: 100
# N° paquetes errados: 14520
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.97096
# Distancia al Rx[m]: 200
# N° paquetes errados: 48559
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.902882
# Distancia al Rx[m]: 300
# N° paquetes errados: 85118
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.829764
# Distancia al Rx[m]: 500
# N° paquetes errados: 152421
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.695158
# Distancia al Rx[m]: 700
# N° paquetes errados: 206683
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.586634
# Distancia al Rx[m]: 1000
# N° paquetes errados: 267465
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.46507
# Distancia al Rx[m]: 2000
# N° paquetes errados: 377657
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.244686
# Distancia al Rx[m]: 3000
# N° paquetes errados: 425095
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.14981
# Distancia al Rx[m]: 5000
# N° paquetes errados: 464813
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.070374
# Distancia al Rx[m]: 7000
# N° paquetes errados: 480694
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.038612
# Distancia al Rx[m]: 10000
# N° paquetes errados: 490555
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.01889
# Channel BW[Hz]: 4000000.0
# N° de constelaciónes QAM: 2
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 7
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 10
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 20
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 30
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 50
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 70
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 100
# N° paquetes errados: 2
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999996
# Distancia al Rx[m]: 200
# N° paquetes errados: 31
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999938
# Distancia al Rx[m]: 300
# N° paquetes errados: 106
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999788
# Distancia al Rx[m]: 500
# N° paquetes errados: 469
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999062
# Distancia al Rx[m]: 700
# N° paquetes errados: 1221
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.997558
# Distancia al Rx[m]: 1000
# N° paquetes errados: 3177
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.993646
# Distancia al Rx[m]: 2000
# N° paquetes errados: 14172
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.971656
# Distancia al Rx[m]: 3000
# N° paquetes errados: 29519
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.940962
# Distancia al Rx[m]: 5000
# N° paquetes errados: 66333
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.867334
# Distancia al Rx[m]: 7000
# N° paquetes errados: 102022
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.795956
# Distancia al Rx[m]: 10000
# N° paquetes errados: 151592
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.696816
# N° de constelaciónes QAM: 4
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 7
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 10
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 20
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 30
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 50
# N° paquetes errados: 1
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999998
# Distancia al Rx[m]: 70
# N° paquetes errados: 6
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999988
# Distancia al Rx[m]: 100
# N° paquetes errados: 13
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999974
# Distancia al Rx[m]: 200
# N° paquetes errados: 137
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999726
# Distancia al Rx[m]: 300
# N° paquetes errados: 493
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999014
# Distancia al Rx[m]: 500
# N° paquetes errados: 2003
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.995994
# Distancia al Rx[m]: 700
# N° paquetes errados: 4682
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.990636
# Distancia al Rx[m]: 1000
# N° paquetes errados: 10214
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.979572
# Distancia al Rx[m]: 2000
# N° paquetes errados: 36757
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.926486
# Distancia al Rx[m]: 3000
# N° paquetes errados: 68576
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.862848
# Distancia al Rx[m]: 5000
# N° paquetes errados: 128723
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.742554
# Distancia al Rx[m]: 7000
# N° paquetes errados: 179974
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.640052
# Distancia al Rx[m]: 10000
# N° paquetes errados: 239443
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.521114
# N° de constelaciónes QAM: 16
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 7
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 10
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 20
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 30
# N° paquetes errados: 3
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999994
# Distancia al Rx[m]: 50
# N° paquetes errados: 22
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999956
# Distancia al Rx[m]: 70
# N° paquetes errados: 60
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.99988
# Distancia al Rx[m]: 100
# N° paquetes errados: 201
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999598
# Distancia al Rx[m]: 200
# N° paquetes errados: 1408
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.997184
# Distancia al Rx[m]: 300
# N° paquetes errados: 3993
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.992014
# ...
#                                 Tasa de trasmisión efectiva: 0.78345
# Distancia al Rx[m]: 700
# N° paquetes errados: 155264
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.689472
# Distancia al Rx[m]: 1000
# N° paquetes errados: 213422
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.573156
# Distancia al Rx[m]: 2000
# N° paquetes errados: 330307
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.339386
# Distancia al Rx[m]: 3000
# N° paquetes errados: 388710
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.22258
# Distancia al Rx[m]: 5000
# N° paquetes errados: 443106
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.113788
# Distancia al Rx[m]: 7000
# N° paquetes errados: 466312
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.067376
# Distancia al Rx[m]: 10000
# N° paquetes errados: 482201
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.035598
# Channel BW[Hz]: 8000000.0
# N° de constelaciónes QAM: 2
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 7
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 10
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 20
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 30
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 50
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 70
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 100
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 200
# N° paquetes errados: 3
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999994
# Distancia al Rx[m]: 300
# N° paquetes errados: 32
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999936
# Distancia al Rx[m]: 500
# N° paquetes errados: 198
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999604
# Distancia al Rx[m]: 700
# N° paquetes errados: 464
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999072
# Distancia al Rx[m]: 1000
# N° paquetes errados: 1317
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.997366
# Distancia al Rx[m]: 2000
# N° paquetes errados: 7183
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.985634
# Distancia al Rx[m]: 3000
# N° paquetes errados: 16326
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.967348
# Distancia al Rx[m]: 5000
# N° paquetes errados: 40619
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.918762
# Distancia al Rx[m]: 7000
# N° paquetes errados: 66749
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.866502
# Distancia al Rx[m]: 10000
# N° paquetes errados: 105580
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.78884
# N° de constelaciónes QAM: 4
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 7
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 10
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 20
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 30
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 50
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 70
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 100
# N° paquetes errados: 4
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999992
# Distancia al Rx[m]: 200
# N° paquetes errados: 53
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999894
# Distancia al Rx[m]: 300
# N° paquetes errados: 218
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999564
# Distancia al Rx[m]: 500
# N° paquetes errados: 840
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.99832
# Distancia al Rx[m]: 700
# N° paquetes errados: 1981
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.996038
# Distancia al Rx[m]: 1000
# N° paquetes errados: 4843
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.990314
# Distancia al Rx[m]: 2000
# N° paquetes errados: 20981
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.958038
# Distancia al Rx[m]: 3000
# N° paquetes errados: 41591
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.916818
# Distancia al Rx[m]: 5000
# N° paquetes errados: 87059
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.825882
# Distancia al Rx[m]: 7000
# N° paquetes errados: 129016
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.741968
# Distancia al Rx[m]: 10000
# N° paquetes errados: 183690
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.63262
# N° de constelaciónes QAM: 16
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 7
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 10
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 20
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 30
# N° paquetes errados: 2
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999996
# Distancia al Rx[m]: 50
# N° paquetes errados: 4
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999992
# Distancia al Rx[m]: 70
# N° paquetes errados: 23
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999954
# Distancia al Rx[m]: 100
# N° paquetes errados: 62
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999876
# Distancia al Rx[m]: 200
# N° paquetes errados: 577
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.998846
# Distancia al Rx[m]: 300
# N° paquetes errados: 1799
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.996402
# Distancia al Rx[m]: 500
# N° paquetes errados: 5899
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.988202
# Distancia al Rx[m]: 700
# N° paquetes errados: 12352
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.975296
# Distancia al Rx[m]: 1000
# N° paquetes errados: 24347
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.951306
# Distancia al Rx[m]: 2000
# N° paquetes errados: 72356
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.855288
# Distancia al Rx[m]: 3000
# N° paquetes errados: 119909
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.760182
# Distancia al Rx[m]: 5000
# N° paquetes errados: 197789
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.604422
# Distancia al Rx[m]: 7000
# N° paquetes errados: 254767
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.490466
# Distancia al Rx[m]: 10000
# N° paquetes errados: 315416
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.369168
# N° de constelaciónes QAM: 64
# Distancia al Rx[m]: 1
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 2
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 3
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 5
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 7
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 10
# N° paquetes errados: 0
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 1.0
# Distancia al Rx[m]: 20
# N° paquetes errados: 3
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999994
# Distancia al Rx[m]: 30
# N° paquetes errados: 10
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.99998
# Distancia al Rx[m]: 50
# N° paquetes errados: 73
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.999854
# Distancia al Rx[m]: 70
# N° paquetes errados: 190
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.99962
# Distancia al Rx[m]: 100
# N° paquetes errados: 581
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.998838
# Distancia al Rx[m]: 200
# N° paquetes errados: 3571
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.992858
# Distancia al Rx[m]: 300
# N° paquetes errados: 8995
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.98201
# Distancia al Rx[m]: 500
# N° paquetes errados: 24399
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.951202
# Distancia al Rx[m]: 700
# N° paquetes errados: 42830
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.91434
# Distancia al Rx[m]: 1000
# N° paquetes errados: 72447
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.855106
# Distancia al Rx[m]: 2000
# N° paquetes errados: 161362
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.677276
# Distancia al Rx[m]: 3000
# N° paquetes errados: 228479
#                                 N° total de paquetes 500000.0
#                                 Tasa de trasmisión efectiva: 0.543042
# Distancia al Rx[m]: 5000

# %%
def plotGraph(data_x, data_y, env, gi, bw, q):
    lenght = len(data_x)
    #x = np.linspace(0, lenght, num=lenght, endpoint=False) ## Equiespaciamos max_In en interval

    # Note that even in the OO-style, we use `.pyplot.figure` to create the figure.
    fig, ax = plt.subplots(figsize=(15,10))  # Create a figure and an axes.
    ax.plot(data_x, data_y, "-bo", label='Goodput')  # Plot some data on the axes.
    ax.set_xlabel('Distancia[m]')  # Add an x-label to the axes.
    ax.set_ylabel('Tasa efectiva paquetes(Goodput)')  # Add a y-label to the axes.
    ax.set_title(f"Goodput. vs Distancia[m]")  # Add a title to the axes.
    ax.legend()  # Add a legend.
    ax.text(6500, 1, f'\n{"#"*len(str(env))}\nAmbiente: {env}\n' +
           f'Guard Interval[us]: {gi/1e-6}\n' +
           f'Bw del canal[MHz]: {bw/1e6}\n' + 
           f'M-QAM: {q}', fontsize=12)
    for i in range(lenght):
        ax.annotate(str(data_x[i]), # this is the text
                     (data_x[i], data_y[i]), # these are the coordinates to position the label
                     textcoords="offset points", # how to position the text
                     xytext=(0,10), # distance from text to points (x,y)
                     ha='center') # horizontal alignment can be left, right or center

# %%
def plotAllGraphs(datos):
    canal_bw = [1e6, 2e6, 4e6, 8e6, 16e6] ## Canales BW
    dist_list = [1, 2, 3, 5, 7, 10,
                 20, 30, 50, 70, 100,
                 200, 300, 500, 700, 1000,
                 2000, 3000, 5000, 7000, 10000] ## Distancias 
    q_am = [2, 4, 16, 64, 256] ## BPSK, QPSK, 16QAM, 64QAM, 256QAM
    gi_list = [4e-6, 8e-6] ## Guard Interval
    data = {}
    tmp = []
    for env in Environment:
        print(env)
        data = {k: v for k, v in datos.items() if k[0]==env}
        for gi in gi_list:
            for bw in canal_bw:
                for q in q_am:
                    tmp = []
                    for dist in dist_list:
                        tmp.append(data[env, gi, bw, q, dist])
                    print(tmp)
                    tmp = np.array(tmp)
                    plotGraph(dist_list, tmp, env, gi, bw, q)

# %%
plotAllGraphs(datos)
